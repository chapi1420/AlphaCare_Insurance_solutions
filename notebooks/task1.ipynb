# %% [markdown]
# # Exporatory Data Analysis
# ## objective
#     * Optimize the marketing strategy.
#     * Discover low risk targets for which the premium could be reduced.
#     * Attract new customers
# ## Data Summarization:
#     * Descriptive Statistics: Computed measures of central tendency (mean, median) and variability (standard deviation, range) for numerical columns.
#     * Data Structure Review: Verified data types for proper formatting, ensuring categorical variables, numerical fields, and dates were correctly defined.
# ## Data Quality Assessment:
#     * Missing Values: Addressed missing data by:
#         * Imputing median values for numerical columns.
#         * Filling mode values for categorical columns.
#     * Outliers: Detected using box plots and handled via capping and replacement to reduce distortion in analysis.
# ### In this notebook:
#     * data is cleaned, summarized and inconvenient columns are droped.

# %%
import os
import sys
sys.path.append(os.path.abspath(".."))

# %%
from scripts.task1 import Eda

# %% [markdown]
# * we imported all the required libraries to load the data we want to process and analyse. Now we will load the data by calling a "load" method in our imported calss, 'Eda'.
# * Expectations of loading the data:
#     * The computer should echo "Data loaded successfully" if the data is successfully loaded.
#     * we can auume that the imported class works properly as long as the first function works. Any code or result errors will be the outcomes of the code imported.

# %%
data = Eda("C:\\Users\\nadew\\10x\\week3\\ACIS\\data\\MachineLearningRating_v4.csv")
# Out:
# Loading data from C:\Users\nadew\10x\week3\ACIS\data\MachineLearningRating_v4.csv
# c:\Users\nadew\10x\week3\ACIS\scripts\task1.py:24: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(self.file_path)
# Data loaded successfully.

# %% [markdown]
# ### Inspecting data
# #### why inspect our data:
#     * this may help us in observing the datatypes of columns.
#     * understand the number of columns in the data we have

# %%
data.inspect_data()
# Out:
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  int64
#  1   PolicyID                  1000098 non-null  int64
#  2   TransactionMonth          1000098 non-null  object
#  3   IsVATRegistered           1000098 non-null  bool
#  4   Citizenship               1000098 non-null  object
#  5   LegalType                 1000098 non-null  object
#  6   Title                     1000098 non-null  object
#  7   Language                  1000098 non-null  object
#  8   Bank                      854137 non-null   object
#  9   AccountType               959866 non-null   object
#  10  MaritalStatus             991839 non-null   object
#  11  Gender                    990562 non-null   object
#  12  Country                   1000098 non-null  object
# ...

# %%
data.eda_summary()
# Out:
# Summary Statistics:
#         UnderwrittenCoverID      PolicyID  ...  TotalPremium   TotalClaims
# count          1.000098e+06  1.000098e+06  ...  1.000098e+06  1.000098e+06
# unique                  NaN           NaN  ...           NaN           NaN
# top                     NaN           NaN  ...           NaN           NaN
# freq                    NaN           NaN  ...           NaN           NaN
# mean           1.048175e+05  7.956682e+03  ...  6.190550e+01  6.486119e+01
# std            6.329371e+04  5.290039e+03  ...  2.302845e+02  2.384075e+03
# min            1.000000e+00  1.400000e+01  ... -7.825768e+02 -1.200241e+04
# 25%            5.514300e+04  4.500000e+03  ...  0.000000e+00  0.000000e+00
# 50%            9.408300e+04  7.071000e+03  ...  2.178333e+00  0.000000e+00
# 75%            1.391900e+05  1.107700e+04  ...  2.192982e+01  0.000000e+00
# max            3.011750e+05  2.324600e+04  ...  6.528260e+04  3.930921e+05
#
# [11 rows x 52 columns]

# %%
columns_req = ['TotalPremium']
data.visualize_distribution(columns_req)

# %% [markdown]
# ## From the given figure, we can observe the following:
# 1. Right-Skewed Distribution: The data is highly skewed to the right, as most of the values are concentrated near zero, with very few high values extending toward larger numbers.
#
# 2. Outliers or High Variance: The long tail on the right suggests there are outliers or a small number of observations with exceptionally high "TotalPremium" values compared to the rest.
#
# 3. Limited Spread: The majority of the data points fall within a narrow range, as seen by the dense clustering near zero.
#
# ## Recommendations:
# 1.  Segment the Customer Base: The highly skewed distribution suggests there are likely distinct customer segments with very different premium profiles. Explore data by  segmenting the customer base to better understand the characteristics and needs of each group.
#
# 2.  Optimize Pricing and Products: The distribution indicates there is likely room to adjust pricing and product offerings to better match the needs of the different customer segments. This could involve introducing new products or adjusting premiums for certain customer groups.
#
# 3.  Enhance Customer Experience: The large number of customers with low premiums suggests there may be opportunities to improve the customer experience and engagement for this group. This could include targeted marketing, improved self-service options, or tailored service models.
#
# 4.  Identify and Retain High-Value Customers: The long tail of the distribution represents the high-value customers generating the largest premiums. I would focus on understanding the needs of these customers and ensuring they receive a superior level of service and attention to retain them.
#
# 5.   Analyze Risk and Underwriting: The distribution provides insights into the overall risk profile of the customer base. I would use this information to review underwriting practices, assess risk exposure, and potentially adjust coverage limits or requirements.

# %%
columns_req = ['TotalClaims']
data.visualize_distribution(columns_req)

# %% [markdown]
# ## observation:
# 1. The graph is skewd to right, this indicates that majority of the customers receive small or no claims.
# 3.  The outlier value is vey big, some more than 350, 000$.
# ## Recommendation:
# 1. Segment the Customer Base: The highly skewed distribution suggests there are likely distinct customer segments with very different claims profiles.
# 2. Optimize Pricing and Underwriting: The distribution indicates there is likely room to adjust pricing and underwriting practices to better match the risk profiles of the different customer segments. This could involve introducing new products, adjusting premiums, or revising coverage limits for certain customer groups.
#
# 3. Enhance Fraud Detection: The long tail of the distribution represents the high-value claims, which may be more susceptible to fraud. I would invest in improving fraud detection and prevention measures to mitigate potential losses.
#
# 4. Improve Claims Management: The large number of customers with low claims suggests there may be opportunities to streamline the claims process and enhance the customer experience for this group. This could include implementing self-service options, automating low-value claims, or providing better guidance on claim submission.

# %%
data.visualize_relationship('TotalPremium', 'TotalClaims')

# %% [markdown]
# ## picture overview
# 1. Relationship between TotalPremium and TotalClaims: The plot shows the relationship between the total premium (TotalPremium) and the total claims (TotalClaims) for the insurance company's customers. Each point on the plot represents an individual customer.
#
# 2. Positive Correlation: The overall trend in the data suggests a positive correlation between TotalPremium and TotalClaims. As the TotalPremium increases, the TotalClaims also tend to increase, though the relationship is not perfectly linear.
#
# 3. Concentration of Low-Value Customers: The majority of the data points are clustered in the bottom-left corner of the plot, indicating a concentration of customers with relatively low TotalPremium and TotalClaims values.
#
# 4. Outliers with High TotalPremium and TotalClaims: There are a few outliers in the top-right corner of the plot, representing customers with significantly higher TotalPremium and TotalClaims values compared to the majority of the customer base.
#
# ## notice
# Given the data being highly skewed, I decided to clean the data first and do the cleaning and visualilzation again in anothe notebook file. The name of the notebook is 'task1_part2' link to the notebook: https://github.com/chapi1420/AlphaCare_Insurance_solutions/blob/master/notebooks/task1_part2.ipynb
